# %%
import matplotlib.pyplot as plt
import numpy as np


def old():
    np.random.seed(19680801)
    data = np.random.random((50, 5, 5))

    fig, ax = plt.subplots()

    for i in range(len(data)):
        ax.cla()
        #data[i]=data[i]>0.5

        ax.imshow(data[i],cmap='RdBu')
        ax.set_title("frame {}".format(i))
        # Note that using time.sleep does *not* work here!
        plt.pause(0.1)

        #plt.colorbar(cmap='RdBu')
    print ("done")

import os
import sys
#sys.path.append(os.path.abspath(os.path.dirname(__file__) + '/' + '../modules'))
sys.path.append(os.path.abspath(os.getcwd() + '/../modules'))


from BaseStructure import BaseStructure
from Components import Abstract, Context1, Context2, Actuator, Spektron
from Veri import Veri
from scipy.io import wavfile
import matplotlib.pyplot as plt
import numpy as np
import playsound
import pyAudioAnalysis
#from python_speech_features import mfcc, logfbank
from fnmatch import fnmatch
import os
from python_speech_features import mfcc, logfbank



def browseFolder( root, pattern):
    print(root)
    lista = []
    # pattern = "*.lyr"
    for path, subdirs, files in os.walk(root):
        # print( path
        for name in files:
            if fnmatch(name.lower(), pattern):
                lista.append(os.path.join(path, name))
    return lista

def learned_weights_x():
    ans = []
    with open('weights.txt', 'r') as weight_file:
        lines = weight_file.readlines()
        for i in lines[0].split('\t'):
            ans.append(float(i))
    return ans

agac = BaseStructure()

x=(browseFolder("../dune","*.txt"))
for i,f in enumerate(x):
    print(i,f, f.split("\\")[-1])
    with open(f, 'r',errors='ignore') as metin:
        lines = metin.readlines()
        print("number of sentences = ",len(lines))
    print(lines[:10])
    for j in range(10):
        print(lines[j].lower().split(),)
        kelimeler = lines[j].lower().split()
        if(len(kelimeler)>0):
            for k,harfler  in enumerate(kelimeler):
                agac.addBranch(list(harfler))

agac.plotGraph()

    #break
# Out:
# ../dune
# 0 ../dune\01 dune.txt 01 dune.txt
# number of sentences =  8610
# ['Dune\n', 'Frank Herbert\n', '\n', '\n', '\n', 'Copyright 1965\n', '\n', 'Book 1\n', 'DUNE\n', '\n']
# ['dune']
# ['frank', 'herbert']
# []
# []
# []
# ['copyright', '1965']
# []
# ['book', '1']
# ['dune']
# []
# 1 ../dune\02 Dune Messiah.txt 02 Dune Messiah.txt
# number of sentences =  3170
# ['Dune Messiah\n', 'Frank Herbert\n', '\n', '\n', 'Copyright 1969\n', '\n', '\n', 'Excerpts from the Death Cell Interview with Bronso of IX\n', '\n', "Q: What led you to take your particular approach to a history of Muad'dib?\n"]
# ['dune', 'messiah']
# ['frank', 'herbert']
# []
# []
# ['copyright', '1969']
# []
# []
# ['excerpts', 'from', 'the', 'death', 'cell', 'interview', 'with', 'bronso', 'of', 'ix']
# []
# ['q:', 'what', 'led', 'you', 'to', 'take', 'your', 'particular', 'approach', 'to', 'a', 'history', 'of', "muad'dib?"]
# 2 ../dune\03 Children of Dune.txt 03 Children of Dune.txt
# number of sentences =  5128
# ['Children of Dune\n', 'Frank Herbert\n', '\n', '\n', 'Copyright 1976\n', '\n', '\n', "Muad'Dib's teachings have become the playground of scholastics, of the superstitious and the corrupt. He taught a balanced way of life, a philosophy with which a human can meet problems arising from an ever-changing universe. He said humankind is still evolving, in a process which will never end. He said this evolution moves on changing principles which are known only to eternity. How can corrupted reasoning play with such an essence?\n", '-Words of the Mentat Duncan Idaho\n', '\n']
# ['children', 'of', 'dune']
# ['frank', 'herbert']
# []
# []
# ['copyright', '1976']
# []
# []
# ["muad'dib's", 'teachings', 'have', 'become', 'the', 'playground', 'of', 'scholastics,', 'of', 'the', 'superstitious', 'and', 'the', 'corrupt.', 'he', 'taught', 'a', 'balanced', 'way', 'of', 'life,', 'a', 'philosophy', 'with', 'which', 'a', 'human', 'can', 'meet', 'problems', 'arising', 'from', 'an', 'ever-changing', 'universe.', 'he', 'said', 'humankind', 'is', 'still', 'evolving,', 'in', 'a', 'process', 'which', 'will', 'never', 'end.', 'he', 'said', 'this', 'evolution', 'moves', 'on', 'changing', 'principles', 'which', 'are', 'known', 'only', 'to', 'eternity.', 'how', 'can', 'corrupted', 'reasoning', 'play', 'with', 'such', 'an', 'essence?']
# ['-words', 'of', 'the', 'mentat', 'duncan', 'idaho']
# []
# 3 ../dune\04 God Emporer of Dune.txt 04 God Emporer of Dune.txt
# number of sentences =  11023
# ['God Emporer of Dune\n', 'Frank Herbert\n', '\n', '\n', '\n', 'Excerpt from the speech by Hadi Benotto announcing the discoveries at Dar-es-Balat on the planet of Rakis:\n', '\n', 'IT NOT only is my pleasure to announce to you this morning our discovery of this marvelous storehouse containing, among other things, a monumental collection of manuscripts inscribed on ridulian crystal paper, but I also take pride in giving you our arguments for the authenticity of our discoveries, to tell you why we believe we have uncovered the original journals of Leto II, the God Emperor.\n', '\n', 'First, let me recall to you the historical treasure which we all know by the name of The Stolen Journals, those volumes of known antiquity which over the centuries have been so valuable in helping us to understand our ancestors. As you all know, The Stolen Journals were deciphered by the Spacing Guild, and the method of the Guild Key was employed to translate these newly discovered volumes. No one denies the antiquity of the Guild Key and it, and it alone, translates these volumes.\n']
# ['god', 'emporer', 'of', 'dune']
# ['frank', 'herbert']
# []
# []
# []
# ['excerpt', 'from', 'the', 'speech', 'by', 'hadi', 'benotto', 'announcing', 'the', 'discoveries', 'at', 'dar-es-balat', 'on', 'the', 'planet', 'of', 'rakis:']
# []
# ['it', 'not', 'only', 'is', 'my', 'pleasure', 'to', 'announce', 'to', 'you', 'this', 'morning', 'our', 'discovery', 'of', 'this', 'marvelous', 'storehouse', 'containing,', 'among', 'other', 'things,', 'a', 'monumental', 'collection', 'of', 'manuscripts', 'inscribed', 'on', 'ridulian', 'crystal', 'paper,', 'but', 'i', 'also', 'take', 'pride', 'in', 'giving', 'you', 'our', 'arguments', 'for', 'the', 'authenticity', 'of', 'our', 'discoveries,', 'to', 'tell', 'you', 'why', 'we', 'believe', 'we', 'have', 'uncovered', 'the', 'original', 'journals', 'of', 'leto', 'ii,', 'the', 'god', 'emperor.']
# []
# ['first,', 'let', 'me', 'recall', 'to', 'you', 'the', 'historical', 'treasure', 'which', 'we', 'all', 'know', 'by', 'the', 'name', 'of', 'the', 'stolen', 'journals,', 'those', 'volumes', 'of', 'known', 'antiquity', 'which', 'over', 'the', 'centuries', 'have', 'been', 'so', 'valuable', 'in', 'helping', 'us', 'to', 'understand', 'our', 'ancestors.', 'as', 'you', 'all', 'know,', 'the', 'stolen', 'journals', 'were', 'deciphered', 'by', 'the', 'spacing', 'guild,', 'and', 'the', 'method', 'of', 'the', 'guild', 'key', 'was', 'employed', 'to', 'translate', 'these', 'newly', 'discovered', 'volumes.', 'no', 'one', 'denies', 'the', 'antiquity', 'of', 'the', 'guild', 'key', 'and', 'it,', 'and', 'it', 'alone,', 'translates', 'these', 'volumes.']
# 4 ../dune\07 House Atreides.txt 07 House Atreides.txt
# number of sentences =  22181
# [' file:///F|/rah/Herbert,%20Frank/Dune%207%20-%20House%20Atreides.txt\n', '\n', 'Dune:     House Atreides\n', '\n', 'Brian Herbert and Kevin J. Anderson\n', 'October 1999\n', '\n', '\n', 'This book is for our mentor, Frank Herbert, who was every bit as fascinating and complex as the\n', 'marvelous Dune universe he created.\n']
# ['file:///f|/rah/herbert,%20frank/dune%207%20-%20house%20atreides.txt']
# []
# ['dune:', 'house', 'atreides']
# []
# ['brian', 'herbert', 'and', 'kevin', 'j.', 'anderson']
# ['october', '1999']
# []
# []
# ['this', 'book', 'is', 'for', 'our', 'mentor,', 'frank', 'herbert,', 'who', 'was', 'every', 'bit', 'as', 'fascinating', 'and', 'complex', 'as', 'the']
# ['marvelous', 'dune', 'universe', 'he', 'created.']
# 5 ../dune\08 House Harkonnen.txt 08 House Harkonnen.txt
# number of sentences =  23208
# [' file:///F|/rah/Herbert,%20Frank/Dune%208%20-%20House%20Harkonnen.txt\n', '\n', 'Dune:     House Harkonnen\n', '\n', 'Brian Herbert and Kevin J. Anderson\n', 'October 2000\n', '\n', '\n', 'To our mutual friend Ed Kramer, without whom this project would never have come to fruition.                         He\n', 'provided the spark that brought us together.\n']
# ['file:///f|/rah/herbert,%20frank/dune%208%20-%20house%20harkonnen.txt']
# []
# ['dune:', 'house', 'harkonnen']
# []
# ['brian', 'herbert', 'and', 'kevin', 'j.', 'anderson']
# ['october', '2000']
# []
# []
# ['to', 'our', 'mutual', 'friend', 'ed', 'kramer,', 'without', 'whom', 'this', 'project', 'would', 'never', 'have', 'come', 'to', 'fruition.', 'he']
# ['provided', 'the', 'spark', 'that', 'brought', 'us', 'together.']
# 6 ../dune\09 The Dune Chronicles.txt 09 The Dune Chronicles.txt
# number of sentences =  21788
# ['ï»¿ Dune\n', '\n', '\n', 'halftitle\n', '\n', '\n', 'The Dune Chronicles by Frank Herbert\n', '\n', 'Dune\n', '\n']
# ['ï»¿', 'dune']
# []
# []
# ['halftitle']
# []
# []
# ['the', 'dune', 'chronicles', 'by', 'frank', 'herbert']
# []
# ['dune']
# []
# 7 ../dune\13 Hunters of Dune.txt 13 Hunters of Dune.txt
# number of sentences =  21411
# ['Heretics of Dune\n', '\n', 'Frank Herbert\n', 'April 1984\n', '\n', '\n', '\n', '\n', 'When I was writing Dune\n', '\n']
# ['heretics', 'of', 'dune']
# []
# ['frank', 'herbert']
# ['april', '1984']
# []
# []
# []
# []
# ['when', 'i', 'was', 'writing', 'dune']
# []
# 8 ../dune\14 The Road To Dune.txt 14 The Road To Dune.txt
# number of sentences =  20396
# ['Chapterhouse:   Dune\n', '\n', 'Frank Herbert\n', 'April 1985\n', '\n', '\n', '\n', '\n', 'Those who would repeat the past must control the teaching of history.\n', '\n']
# ['chapterhouse:', 'dune']
# []
# ['frank', 'herbert']
# ['april', '1985']
# []
# []
# []
# []
# ['those', 'who', 'would', 'repeat', 'the', 'past', 'must', 'control', 'the', 'teaching', 'of', 'history.']
# []
# 9 ../dune\dune 07.txt dune 07.txt
# number of sentences =  16580
# ['=================================================\n', 'Notes:\n', 'This book was scanned by JASC/elibrary\n', 'If you correct any errors, please change the version number below (and in the file\n', 'name) to a slightly higher one e.g. from .9 to .95 , or if major revisions + proof, to v.\n', '1.0 or higher.\n', 'Current e-book version is v .9\n', 'Comments, Questions, Requests(no promises): daytonascan4911@hotmail.com\n', 'DO NOT READ THIS BOOK OF YOU DO NOT OWN/POSSES THE PHYSICAL\n', 'COPY. THAT IS STEALING FROM THE AUTHOR.\n']
# ['=================================================']
# ['notes:']
# ['this', 'book', 'was', 'scanned', 'by', 'jasc/elibrary']
# ['if', 'you', 'correct', 'any', 'errors,', 'please', 'change', 'the', 'version', 'number', 'below', '(and', 'in', 'the', 'file']
# ['name)', 'to', 'a', 'slightly', 'higher', 'one', 'e.g.', 'from', '.9', 'to', '.95', ',', 'or', 'if', 'major', 'revisions', '+', 'proof,', 'to', 'v.']
# ['1.0', 'or', 'higher.']
# ['current', 'e-book', 'version', 'is', 'v', '.9']
# ['comments,', 'questions,', 'requests(no', 'promises):', 'daytonascan4911@hotmail.com']
# ['do', 'not', 'read', 'this', 'book', 'of', 'you', 'do', 'not', 'own/posses', 'the', 'physical']
# ['copy.', 'that', 'is', 'stealing', 'from', 'the', 'author.']
# 10 ../dune\dune 08.txt dune 08.txt
# number of sentences =  29990
# ['Herbert, Brian & Anderson, Kevin - The Machine Crusade\n', '\n', '\n', '\n', '\n', '                LEGENDS OF DUNE\n', '                                          THE MACHINE CRUSADE\n', '\n', '\n', '\n']
# ['herbert,', 'brian', '&', 'anderson,', 'kevin', '-', 'the', 'machine', 'crusade']
# []
# []
# []
# []
# ['legends', 'of', 'dune']
# ['the', 'machine', 'crusade']
# []
# []
# []
# 11 ../dune\dune06.txt dune06.txt
# number of sentences =  18165
# ['                                               Dune\n', '\n', '                                    House Corrino\n', '\n', '           Brian Herbert and Kevin J. Anderson\n', '\n', 'The axis of spin for the planet Arrakis is at right angles to the radius of its orbit. The world itself is\n', 'not a globe, but more a spinning top somewhat fat at the equator and concave toward the poles.\n', 'There is a sense that this may be artificial, the product of some ancient artifice.\n', '\n']
# ['dune']
# []
# ['house', 'corrino']
# []
# ['brian', 'herbert', 'and', 'kevin', 'j.', 'anderson']
# []
# ['the', 'axis', 'of', 'spin', 'for', 'the', 'planet', 'arrakis', 'is', 'at', 'right', 'angles', 'to', 'the', 'radius', 'of', 'its', 'orbit.', 'the', 'world', 'itself', 'is']
# ['not', 'a', 'globe,', 'but', 'more', 'a', 'spinning', 'top', 'somewhat', 'fat', 'at', 'the', 'equator', 'and', 'concave', 'toward', 'the', 'poles.']
# ['there', 'is', 'a', 'sense', 'that', 'this', 'may', 'be', 'artificial,', 'the', 'product', 'of', 'some', 'ancient', 'artifice.']
# []
# 12 ../dune\hunters of dune.txt hunters of dune.txt
# number of sentences =  19340
# ['HUNTERS OF\n', '\n', 'DUNE\n', '\n', '2\n', '\n', 'THE DUNE SERIES\n', '\n', 'BY FRANK HERBERT\n', '\n']
# ['hunters', 'of']
# []
# ['dune']
# []
# ['2']
# []
# ['the', 'dune', 'series']
# []
# ['by', 'frank', 'herbert']
# []
# 13 ../dune\the road to.txt the road to.txt
# number of sentences =  9079
# ['\x0cTHE ROAD TO\n', '\n', '\n', '\n', 'DUNE\n', 'THE DUNE SERIES\n', "FRANK HERBERT'S DUNE NOVELS\n", 'Dune             God Emperor of Dune\n', 'Dune Messiah            Heretics of Dune\n', 'Children of Dune        Chapterhouse: Dune\n']
# ['the', 'road', 'to']
# []
# []
# []
# ['dune']
# ['the', 'dune', 'series']
# ['frank', "herbert's", 'dune', 'novels']
# ['dune', 'god', 'emperor', 'of', 'dune']
# ['dune', 'messiah', 'heretics', 'of', 'dune']
# ['children', 'of', 'dune', 'chapterhouse:', 'dune']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_agraph.py in pygraphviz_layout(G, prog, root, args)
#     282     try:
# --> 283         import pygraphviz
#     284     except ImportError:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-f20440c6a7c5> in <module>
#      77                 agac.addBranch(list(harfler))
#      78
# ---> 79 agac.plotGraph()
#      80
#      81     #break
#
# ~\Documents\Python Scripts\test1\test1\modules\BaseStructure.py in plotGraph(self, title, short)
#     108             labels = dict((n, d['value']) for n, d in self.agac.nodes(data=True))
#     109             # pos=nx.graphviz_layout(GG, prog='dot')
# --> 110             pos = graphviz_layout(self.agac, prog='dot')
#     111             # nx.spring_layout(GG)
#     112
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_agraph.py in graphviz_layout(G, prog, root, args)
#     241
#     242     """
# --> 243     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#     244
#     245
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_agraph.py in pygraphviz_layout(G, prog, root, args)
#     284     except ImportError:
#     285         raise ImportError('requires pygraphviz ',
# --> 286                           'http://pygraphviz.github.io/')
#     287     if root is not None:
#     288         args += "-Groot=%s" % root
#
# ImportError: ('requires pygraphviz ', 'http://pygraphviz.github.io/')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELLWS1\\Documents\\Python Scripts\\test1\\test1\\probability'
